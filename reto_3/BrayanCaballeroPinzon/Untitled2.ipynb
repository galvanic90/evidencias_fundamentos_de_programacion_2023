# %%
# Diccionario para almacenar los datos del cultivo de arroz
arroz = {
    "Origen": "El cultivo del arroz comenzó hace casi 10.000 años, en muchas regiones húmedas de Asia tropical y subtropical. Posiblemente sea la India el país donde se cultivó por primera vez el arroz debido a que en ella abundaban los arroces silvestres. Pero el desarrollo del cultivo tuvo lugar en China, desde sus tierras bajas a sus tierras altas. Probablemente hubo varias rutas por las cuales se introdujeron los arroces de Asia a otras partes del mundo..",
    "Importancia": "El arroz es el alimento básico para más de la mitad de la población mundial, aunque es el más importante del mundo si se considera la extensión de la superficie en que se cultiva y la cantidad de gente que depende de su cosecha. A nivel mundial, el arroz ocupa el segundo lugar después del trigo si se considera la superficie cosechada, pero si se considera su importancia como cultivo alimenticio, el arroz proporciona más calorías por hectárea que cualquier otro cultivo de cereales. Además de su importancia como alimento, el arroz proporciona empleo al mayor sector de la población rural de la mayor parte de Asia, pues es el cereal típico del Asia meridional y oriental, aunque también es ampliamente cultivado en África y en América, y no sólo ampliamente sino intensivamente en algunos puntos de Europa meridional, sobre todo en las regiones mediterráneas..",
    "Mercado": "Debido a las características del mercado mundial del arroz, este contribuye a la volatilidad de los precios. Por tanto se consideran los siguientes aspectos en el mercado internacional del arroz: destacan las pequeñas cantidades comercializadas respecto a las cantidades producidas o consumidas, por ello pequeños cambios en la producción o en el consumo de alguno de los principales productores/consumidores o países compradores vendedores, puede dar lugar a un gran impacto sobre el volumen puesto en el mercado y por tanto, sobre los precios..",
    "Clima": "Se trata de un cultivo tropical y subtropical, aunque la mayor producción a nivel mundial se concentra en los climas húmedos tropicales, pero también se puede cultivar en las regiones húmedas de los subtropicos y en climas templados. El cultivo se extiende desde los 49-50º de latitud norte a los 35º de latitud sur. El arroz se cultiva desde el nivel del mar hasta los 2.500 m. de altitud. Las precipitaciones condicionan el sistema y las técnicas de cultivo, sobre todo cuando se cultivan en tierras altas, donde están más influenciadas por la variabilidad de las mismas.."
    }

# Función para imprimir las opciones de datos del cultivo de arroz
def imprimir_opciones_datos():
    print("\nOpciones de Datos del Cultivo de Arroz:")
    i = 1
    for dato in arroz.keys():
        print(f"{i}. {dato}")
        i += 1

# Función para mostrar la definición de un dato del cultivo de arroz
def mostrar_definicion(dato_seleccionado):
    if dato_seleccionado in arroz:
        print(f"Definición de '{dato_seleccionado}': {arroz[dato_seleccionado]}")
    else:
        print(f"Dato '{dato_seleccionado}' no encontrado.")

###Diccionario para horario y gestión del cultivo
cultivo = {
    "Regado": "Lunes a Domingo. 7:00 pm.",
    "Abono": "Lunes, Miercoles, Viernes. 5:00 pm.",
    "Mantenimiento": "Lunes a Viernes. 8:00 am.",
    }

# Función para imprimir las opciones de datos del horario
def imprimir_opciones_datoss():
    print("\nOpciones de horarios y gestión del cultivo:")
    i = 1
    for dato in cultivo.keys():
        print(f"{i}. {dato}")
        i += 1

# Función para mostrar la definición de un dato del horario
def mostrar_definicion(seleccion_datos):
    if seleccion_datos in cultivo:
        print(f"Definición de '{seleccion_datos}': {cultivo[seleccion_datos]}")
    else:
        print(f"Dato '{seleccion_datos}' no encontrado.")

###Diccionario para etapas del cultivo
etapas = {
    "Vegetativa": "La germinación y el desarrollo de la plántula óptimo comienza cuando la dormancia de las semillas se rompe, esto se logra mediante la absorción de una adecuada cantidad de agua y la exposición a temperaturas entre 20-40ºC, óptima 30-35ºC.",
    "Reproductiva": "se caracteriza por un declinamiento del número de macollos, la emergencia de la hoja bandera, el engrosamiento del tallo por el crecimiento interno de la panoja, la emergencia de la panoja (ocurre unos a 20-25 días luego de la diferenciación del primordio floral), y la floración (antesis)..",
    "Maduración": "Una variedad de 120 días pasa unos 55-60 días en la fase vegetativa, 30 días en la fase reproductiva, y 30 días en la fase de madurez.",
    }

# Función para imprimir las opciones de etapas del cultivo
def imprimir_opciones_etapas():
    print("\nOpciones de horarios y gestión del cultivo:")
    i = 1
    for dato in etapas.keys():
        print(f"{i}. {dato}")
        i += 1

# Función para mostrar la definición de etapas del cultivo
def mostrar_definicion(seleccion_datos):
    if seleccion_datos in etapas:
        print(f"Definición de '{seleccion_datos}': {etapas[seleccion_datos]}")
    else:
        print(f"Dato '{seleccion_datos}' no encontrado.")


###Diccionario para SALIR
salir = {
    "Salir": "Salir.",
      }

# Función para imprimir las opciones de etapas del cultivo
def imprimir_opciones_salir():
    print("\nSalir:")
    i = 1
    for dato in salir.keys():
        print(f"{i}. {dato}")
        i += 1

# Función para mostrar la definición de etapas del cultivo
def mostrar_definicion(seleccion_datos):
    if seleccion_datos in salir:
        print(f"Definición de '{seleccion_datos}': {salir[seleccion_datos]}")
    else:
        print(f"Dato '{seleccion_datos}' no encontrado.")


# Función para mostrar el primer submenú
def submenu_1():
    while True:
        print("\nCostos Mano de obra:")
        print("1. COSTOS")
        print("2. PRODUCCIÓN")

        opcion = input("Seleccione una opción (1/2/3/4/5): ")
        if opcion == "1":
            print("Detalles de MANO DE OBRA")
            # Agregar lógica para mostrar detalles de MANO DE OBRA
        elif opcion == "2":
            print("Detalles de AGUA")
            break
        else:
            print("Opción no válida. Por favor, elija una opción válida.")

# Menú principal
def main():
    print("BIENVENIDO A CULTI-REX")
    print("Somos tu socio confiable en el mundo de la agricultura y la producción de cultivos.")
    print("-" * 80)

    while True:
        print("\nMenú de Gestión de Cultivos:")
        print("1. DATOS DEL CULTIVO")
        print("2. HORARIO Y GESTIÓN DEL CULTIVO")
        print("3. ETAPAS DEL CULTIVO")
        print("4. INFORMACIÓN CONTABLE")
        print("5. SALIR")

        opcion = input("Seleccione una opción (1/2/3/4/5): ")

        if opcion == "1":
            imprimir_opciones_datos()
            seleccion_datos = input("Seleccione un dato (1/2/3/4): ")
            mostrar_definicion(list(arroz.keys())[int(seleccion_datos) - 1])


        elif opcion == "2":
              imprimir_opciones_datoss()
              seleccion_datos = input("Seleccione un dato (1/2/3): ")
              mostrar_definicion(list(cultivo.keys())[int(seleccion_datos) - 1])

        elif opcion == "3":
              imprimir_opciones_etapas()
              seleccion_datos = input("Seleccione un dato (1/2/3): ")
              mostrar_definicion(list(etapas.keys())[int(seleccion_datos) - 1])

        elif opcion == "4":
            submenu_1()  # Llamada al primer submenú

        elif opcion == "5":
              imprimir_opciones_salir()
              seleccion_datos = input("Seleccione un dato (1/2/3): ")
              mostrar_definicion(list(salir.keys())[int(seleccion_datos) - 1])
              break
        else:
            print("Opción no válida. Por favor, elija una opción válida.")

if __name__ == "__main__":
    main()
# Out:
# BIENVENIDO A CULTI-REX
# Somos tu socio confiable en el mundo de la agricultura y la producción de cultivos.
# --------------------------------------------------------------------------------
#
# Menú de Gestión de Cultivos:
# 1. DATOS DEL CULTIVO
# 2. HORARIO Y GESTIÓN DEL CULTIVO
# 3. ETAPAS DEL CULTIVO
# 4. INFORMACIÓN CONTABLE
# 5. SALIR
# Seleccione una opción (1/2/3/4/5): 4
#
# Costos Mano de obra:
# 1. COSTOS
# 2. PRODUCCIÓN
# Seleccione una opción (1/2/3/4/5): 1
# Detalles de MANO DE OBRA
#
# Costos Mano de obra:
# 1. COSTOS
# 2. PRODUCCIÓN
